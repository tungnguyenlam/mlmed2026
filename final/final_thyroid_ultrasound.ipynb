# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sowmyaabirami/thyroid-ultrasound-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 285M/285M [01:08<00:00, 4.37MB/s]
# Extracting files...
# Path to dataset files: /Volumes/HP_P900/Users/tungnguyen/.cache/kagglehub/datasets/sowmyaabirami/thyroid-ultrasound-dataset/versions/1

# %%
import os

print(os.listdir(path))

malignant_path_dir = os.path.join(path, "malignant")
# os.listdir(os.path.join(path, "malignant")) # List of image files!

malignant_path_list = os.listdir(malignant_path_dir)
print(len(malignant_path_list))

benign_path_dir = os.path.join(path, "benign")

benign_path_list = os.listdir(benign_path_dir)
print(len(benign_path_list))
# Out:
# ['malignant', 'benign']
# 4780
# 2278
