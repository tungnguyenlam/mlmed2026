# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("thanhbnhphan/hc18-grand-challenge")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Volumes/HP_P900/Users/tungnguyen/.cache/kagglehub/datasets/thanhbnhphan/hc18-grand-challenge/versions/1

# %%
import os

os.listdir(path)
# Out:
# ['training_set_pixel_size_and_HC.csv',
#  'test_set_pixel_size.csv',
#  'training_set',
#  'test_set']

# %%
import pandas as pd

df_train = pd.read_csv(os.path.join(path, "training_set_pixel_size_and_HC.csv"))
df_test = pd.read_csv(os.path.join(path, "test_set_pixel_size.csv"))

# %%
df_train.head()
# Out:
#      filename  pixel size(mm)  head circumference (mm)
# 0  000_HC.png        0.069136                    44.30
# 1  001_HC.png        0.089659                    56.81
# 2  002_HC.png        0.062033                    68.75
# 3  003_HC.png        0.091291                    69.00
# 4  004_HC.png        0.061240                    59.81

# %%
import cv2 

training_image_dir = os.path.join(path, "training_set")
test_image_dir = os.path.join(path, "test_set")

img = cv2.imread(os.path.join(training_image_dir, "000_HC.png"))

import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
df_test.head()
# Out:
#      filename  pixel size(mm)
# 0  000_HC.png        0.235857
# 1  001_HC.png        0.067973
# 2  002_HC.png        0.165202
# 3  003_HC.png        0.096674
# 4  004_HC.png        0.202203

# %%
print(len(df_train))
print(len(df_test))
# Out:
# 999
# 335
